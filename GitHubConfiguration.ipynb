# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd DetectionProject
# %ls
# Out:
# /content/drive/MyDrive/GitHubChristopher/DetectionProject
# GitHubConfiguration.ipynb

# %%
# !git config --global user.email "h8799r@gmail.com"
# !git config --global user.name "CodingWand"
git_token = "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";
# !git add .
# !git commit -m "Création d'un tuto de publication sur GitHub"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@5092a5d4c904.(none)')
